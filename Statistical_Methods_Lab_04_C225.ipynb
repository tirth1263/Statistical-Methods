# %%
import numpy as np
import pandas as pd

# %%
from  google.colab import files
uploaded=files.upload()
# Out:
#      <input type="file" id="files-3e1f744c-d3b8-4d3d-8bc6-65e331796987" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3e1f744c-d3b8-4d3d-8bc6-65e331796987">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('churn-bigml-80.csv')
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 2661    SC              79        415                 No              No
# 2662    AZ             192        415                 No             Yes
# 2663    WV              68        415                 No              No
# 2664    RI              28        510                 No              No
# 2665    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
# ...

# %%
df.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %%
df['State'].unique().shape
# Out:
# (51,)

# %%
print(type(df['State']))
# Out:
# <class 'pandas.core.series.Series'>

# %%
df[df['State']== 'KS']
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 145     KS              70        408                 No              No
# 231     KS             137        408                 No              No
# 299     KS             132        415                 No              No
# 308     KS             127        415                 No              No
# 314     KS             137        415                 No              No
# 348     KS              46        510                 No              No
# 365     KS              86        408                 No             Yes
# 407     KS             143        408                 No             Yes
# 493     KS             110        415                Yes              No
# 494     KS             163        415                 No              No
# 550     KS              99        415                 No              No
# ...

# %%
df[(df['State']== 'KS') & (df['International plan']== 'Yes')]
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 493     KS             110        415                Yes              No
# 616     KS             103        408                Yes              No
# 782     KS             110        415                Yes             Yes
# 1744    KS              47        510                Yes              No
# 2125    KS              91        408                Yes              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 493                       0              293.3               79
# 616                       0               62.8              124
# 782                      27              267.9              103
# 1744                      0               47.8              120
# 2125                      0              246.4              110
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# ...

# %%
df_ks = df[(df['State']== 'KS') & (df['International plan']== 'Yes')]

# %%
df_ks.shape
# Out:
# (5, 20)

# %%
df.groupby(by='State')['Total day minutes'].sum()
# Out:
# State
# AK     7745.7
# AL    12432.6
# AR     8210.7
# AZ     7818.7
# CA     4338.8
# CO    10591.3
# CT    10282.6
# DC     7548.2
# DE     8850.3
# FL     9643.2
# GA     9137.9
# HI     7598.8
# IA     6924.4
# ID     9768.6
# IL     7648.3
# IN    10634.2
# KS    10201.3
# KY     7544.0
# LA     6006.2
# MA     9192.6
# MD    11916.9
# ME     8940.4
# MI    10384.5
# MN    12572.6
# MO     8675.1
# MS     8325.5
# MT     9196.8
# NC    10387.6
# ND     8194.4
# NE     8026.0
# NH     7633.5
# NJ     9954.3
# NM     7642.1
# NV    10842.8
# NY    11742.7
# OH    12189.5
# OK     9360.0
# OR    10563.3
# PA     7063.6
# RI     8365.0
# SC     7963.9
# SD     9378.8
# TN     7496.7
# TX     9956.7
# UT    11014.1
# VA    11997.9
# VT    10437.5
# WA     8422.2
# WI    10722.3
# WV    15137.1
# WY    11875.8
# Name: Total day minutes, dtype: float64

# %%
df.groupby(by='State')['Total intl minutes'].sum()
# Out:
# State
# AK    435.8
# AL    672.8
# AR    492.5
# AZ    477.7
# CA    243.6
# CO    576.9
# CT    587.0
# DC    485.2
# DE    527.9
# FL    536.7
# GA    507.5
# HI    443.3
# IA    370.4
# ID    580.8
# IL    463.0
# IN    527.9
# KS    566.9
# KY    466.6
# LA    320.2
# MA    519.3
# MD    644.4
# ME    487.9
# MI    611.9
# MN    729.3
# MO    522.0
# MS    501.0
# MT    566.9
# NC    560.2
# ND    410.7
# NE    482.8
# NH    448.7
# NJ    561.2
# NM    447.0
# NV    614.9
# NY    694.7
# OH    680.3
# OK    549.5
# OR    652.3
# PA    375.2
# RI    484.8
# SC    482.1
# SD    482.6
# TN    427.6
# TX    582.2
# UT    598.6
# VA    707.8
# VT    574.6
# WA    466.2
# WI    587.7
# WV    872.3
# WY    682.5
# Name: Total intl minutes, dtype: float64

# %%
df['Total calls']=df['Total intl calls']+df['Total night calls']+df['Total day calls']
df
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 0       KS             128        415                 No             Yes
# 1       OH             107        415                 No             Yes
# 2       NJ             137        415                 No              No
# 3       OH              84        408                Yes              No
# 4       OK              75        415                Yes              No
# ...    ...             ...        ...                ...             ...
# 2661    SC              79        415                 No              No
# 2662    AZ             192        415                 No             Yes
# 2663    WV              68        415                 No              No
# 2664    RI              28        510                 No              No
# 2665    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.head(2)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                     25              265.1              110
# 1                     26              161.6              123
#
#    Total day charge  Total eve minutes  ...  Total eve charge  \
# 0             45.07              197.4  ...             16.78
# 1             27.47              195.5  ...             16.62
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3                2.7
# 1                13.7                 3                3.7
#
# ...

# %%
df['Area code']=df['Area code'].astype(str)
df
# Out:
#      State  Account length Area code International plan Voice mail plan  \
# 0       KS             128       415                 No             Yes
# 1       OH             107       415                 No             Yes
# 2       NJ             137       415                 No              No
# 3       OH              84       408                Yes              No
# 4       OK              75       415                Yes              No
# ...    ...             ...       ...                ...             ...
# 2661    SC              79       415                 No              No
# 2662    AZ             192       415                 No             Yes
# 2663    WV              68       415                 No              No
# 2664    RI              28       510                 No              No
# 2665    TN              74       415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of      State  Account length Area code International plan Voice mail plan  \
# 0       KS             128       415                 No             Yes
# 1       OH             107       415                 No             Yes
# 2       NJ             137       415                 No              No
# 3       OH              84       408                Yes              No
# 4       OK              75       415                Yes              No
# ...    ...             ...       ...                ...             ...
# 2661    SC              79       415                 No              No
# 2662    AZ             192       415                 No             Yes
# 2663    WV              68       415                 No              No
# 2664    RI              28       510                 No              No
# 2665    TN              74       415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# ...

# %%
a = '100'

# %%
b=int(a)
